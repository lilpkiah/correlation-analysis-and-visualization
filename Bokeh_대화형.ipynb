# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# 스캐터 relation

p = figure(plot_width=800, plot_height=400)
show(p)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1003', ...)
#   <div class="bk-root" id="1da07fb1-d24e-4fe8-bdd7-1547091ba1de" data-root-id="1003"></div>

# %%
x=[0,1,2,3,4,5]
y=[0,1,2,3,4,5]
p.circle(x,y,size=10)
show(p)
# Out:
#   <div class="bk-root" id="488c11c4-7d3e-470f-b66d-ce38963471fd" data-root-id="1003"></div>

# %%
p=figure(plot_width=700, plot_height=300, x_axis_type)

# %%
import jinja2
from bokeh.embed import components
template=jinja2.Template('''
<html>
<head>
<link href='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css' rel='stylesheet' type='text/css'>
<script src='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.js'></script>
<title>bokeh></title>
</head>
<body>
<h1>This site for Bokeh Test</h1>
이 사이트는 보케를 테스트하기 위한 공간입니다.
{{script}}
{{div}}
</body>
</html>
''')

# %%
script, div = components(p)
from IPython.display import HTML
HTML(template.render(script=script, div=div))
# Out:
# <html>
# <head>
# <link href='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.css' rel='stylesheet' type='text/css'>
# <script src='http://cdn.pydata.org/bokeh/release/bokeh-2.3.2.min.js'></script>
# <title>bokeh></title>
# </head>
# <body>
# <h1>This site for Bokeh Test</h1>
# 이 사이트는 보케를 테스트하기 위한 공간입니다.
#
# <script type="text/javascript">
#     (function() {
#           var fn = function() {
#             Bokeh.safely(function() {
#               (function(root) {
#                 function embed_document(root) {
#
# ...

# %%
with open('data/a.html','w') as f:
    f.write(template.render(script=script, div=div))
