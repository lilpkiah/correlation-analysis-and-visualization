# %%
import pandas as pd
pd.set_option('mode.chained_assignment', None) # Warnin 방지용
import numpy as np

accident = pd.read_excel('data/노인_교통사고건수_시도_시_군_구.xlsx')
accident.head()
# Out:
#   행정구역별(1) 행정구역별(2)  사고건수 (건) 사망자수 (명)  부상자수 (명)
# 0       전국       소계     35312     1342     38147
# 1    서울특별시       소계      5056       86      5279
# 2    서울특별시      종로구       147        2       153
# 3    서울특별시       중구       161        2       163
# 4    서울특별시      용산구        95        4        97

# %%
accident = accident.rename(columns = {'행정구역별(1)' : '시도', '행정구역별(2)' : '군구'})
accident.head()
# Out:
#       시도   군구  사고건수 (건) 사망자수 (명)  부상자수 (명)
# 0     전국   소계     35312     1342     38147
# 1  서울특별시   소계      5056       86      5279
# 2  서울특별시  종로구       147        2       153
# 3  서울특별시   중구       161        2       163
# 4  서울특별시  용산구        95        4        97

# %%
for element in range(0, len(accident)):
    accident['군구'][element] = accident['군구'][element].strip()

# %%
accident['시도군구']=accident.apply(lambda r: r['시도'] + ' ' + r['군구'], axis=1)
accident.head()
# Out:
#       시도   군구  사고건수 (건) 사망자수 (명)  부상자수 (명)       시도군구
# 0     전국   소계     35312     1342     38147      전국 소계
# 1  서울특별시   소계      5056       86      5279   서울특별시 소계
# 2  서울특별시  종로구       147        2       153  서울특별시 종로구
# 3  서울특별시   중구       161        2       163   서울특별시 중구
# 4  서울특별시  용산구        95        4        97  서울특별시 용산구

# %%
accident = accident[accident.군구 != '소계']
accident.head()
# Out:
#               시도   군구  사고건수 (건) 사망자수 (명)  부상자수 (명)
# 시도군구
# 서울특별시 종로구  서울특별시  종로구       147        2       153
# 서울특별시 중구   서울특별시   중구       161        2       163
# 서울특별시 용산구  서울특별시  용산구        95        4        97
# 서울특별시 성동구  서울특별시  성동구       158        6       159
# 서울특별시 광진구  서울특별시  광진구       102        2       106

# %%
accident = accident.set_index('시도군구')
accident.head()
# Out:
#               시도   군구  사고건수 (건) 사망자수 (명)  부상자수 (명)
# 시도군구
# 서울특별시 종로구  서울특별시  종로구       147        2       153
# 서울특별시 중구   서울특별시   중구       161        2       163
# 서울특별시 용산구  서울특별시  용산구        95        4        97
# 서울특별시 성동구  서울특별시  성동구       158        6       159
# 서울특별시 광진구  서울특별시  광진구       102        2       106

# %%
from matplotlib import pyplot as plt
from matplotlib import rcParams, style
style.use('ggplot')

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
import os
path = os.getcwd()

# %%
data_draw_korea = pd.read_csv(path+'/data/data_draw_korea.csv', index_col=0, encoding='UTF-8', engine='python')
data_draw_korea.head()
# Out:
#       인구수 shortName   x  y       면적 광역시도 행정구역
# 0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2   86747        동해  11  5   180.01  강원도  동해시
# 3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4   76733        속초   9  1   105.25  강원도  속초시

# %%
data_draw_korea['시도군구']=data_draw_korea.apply(lambda r: r['광역시도'] + ' ' + r['행정구역'], axis=1)
data_draw_korea = data_draw_korea.set_index("시도군구")
data_draw_korea.head()
# Out:
#             인구수 shortName   x  y       면적 광역시도 행정구역
# 시도군구
# 강원도 강릉시  202520        강릉  11  4  1040.07  강원도  강릉시
# 강원도 고성군   25589    고성(강원)   9  0   664.19  강원도  고성군
# 강원도 동해시   86747        동해  11  5   180.01  강원도  동해시
# 강원도 삼척시   63986        삼척  11  8  1185.80  강원도  삼척시
# 강원도 속초시   76733        속초   9  1   105.25  강원도  속초시

# %%
data_draw_korea_accident = pd.merge(data_draw_korea, accident, how='outer', left_index=True, right_index=True)
data_draw_korea_accident.head()
# Out:
#               인구수 shortName     x    y       면적 광역시도 행정구역   시도   군구  사고건수 (건)  \
# 시도군구
# 강원도 강릉시  202520.0        강릉  11.0  4.0  1040.07  강원도  강릉시  강원도  강릉시     154.0
# 강원도 고성군   25589.0    고성(강원)   9.0  0.0   664.19  강원도  고성군  강원도  고성군      28.0
# 강원도 동해시   86747.0        동해  11.0  5.0   180.01  강원도  동해시  강원도  동해시      60.0
# 강원도 삼척시   63986.0        삼척  11.0  8.0  1185.80  강원도  삼척시  강원도  삼척시      95.0
# 강원도 속초시   76733.0        속초   9.0  1.0   105.25  강원도  속초시  강원도  속초시      73.0
#
#         사망자수 (명)  부상자수 (명)
# 시도군구
# 강원도 강릉시        4     177.0
# 강원도 고성군        1      30.0
# 강원도 동해시        1      69.0
# 강원도 삼척시        1     107.0
# 강원도 속초시        -      86.0

# %%
BORDER_LINES = [
    [(3, 2), (5, 2), (5, 3), (9, 3), (9, 1)], # 인천
    [(2, 5), (3, 5), (3, 4), (8, 4), (8, 7), (7, 7), (7, 9), (4, 9), (4, 7), (1, 7)], # 서울
    [(1, 6), (1, 9), (3, 9), (3, 10), (8, 10), (8, 9),
     (9, 9), (9, 8), (10, 8), (10, 5), (9, 5), (9, 3)], # 경기도
    [(9, 12), (9, 10), (8, 10)], # 강원도
    [(10, 5), (11, 5), (11, 4), (12, 4), (12, 5), (13, 5),
     (13, 4), (14, 4), (14, 2)], # 충청남도
    [(11, 5), (12, 5), (12, 6), (15, 6), (15, 7), (13, 7),
     (13, 8), (11, 8), (11, 9), (10, 9), (10, 8)], # 충청북도
    [(14, 4), (15, 4), (15, 6)], # 대전시
    [(14, 7), (14, 9), (13, 9), (13, 11), (13, 13)], # 경상북도
    [(14, 8), (16, 8), (16, 10), (15, 10),
     (15, 11), (14, 11), (14, 12), (13, 12)], # 대구시
    [(15, 11), (16, 11), (16, 13)], # 울산시
    [(17, 1), (17, 3), (18, 3), (18, 6), (15, 6)], # 전라북도
    [(19, 2), (19, 4), (21, 4), (21, 3), (22, 3), (22, 2), (19, 2)], # 광주시
    [(18, 5), (20, 5), (20, 6)], # 전라남도
    [(16, 9), (18, 9), (18, 8), (19, 8), (19, 9), (20, 9), (20, 10)], # 부산시
]

# %%
def draw_blockMap(blockedMap, targetData, title, color ):
    whitelabelmin = (max(blockedMap[targetData]) - min(blockedMap[targetData])) * 0.25 + min(blockedMap[targetData])
    
    datalabel = targetData
    vmin = min(blockedMap[targetData])
    vmax = max(blockedMap[targetData])
    mapdata = blockedMap.pivot(index = 'y', columns = 'x', values = targetData)
    masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)
    
    plt.figure(figsize = (8, 13))
    plt.title(title)
    plt.pcolor(masked_mapdata, vmin = vmin, vmax = vmax, cmap = color, edgecolor = '#aaaaaa', linewidth = 0.5)
    
    #지역 이름 표시
    for idx, row in blockedMap.iterrows():
        annocolor = 'white' if row[targetData] > whitelabelmin else 'black'
        
        #광역시는 구 이름이 겹치는 경우가 많아서 시단위 이름도 같이 표시
        if row['광역시도'].endswith('시') and not row['광역시도'].startswith('세종'):
            dispname = '{}\n{}'.format(row['광역시도'][:2], row['행정구역'][:-1])
            if len(row['행정구역']) <= 2:
                dispname += row['행정구역'][-1]
        else:
            dispname = row['행정구역'][:-1]
        
        #서대문구, 서귀포시 같이 이름이 3자 이상이면 작은 글자로 표시
        if len(dispname.splitlines()[-1]) >= 3:
            fontsize, linespacing = 9.5, 1.5
        else:
            fontsize, linespacing = 11, 1.2
            
        plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight = 'bold',
            fontsize = fontsize, ha = 'center', va = 'center', color = annocolor, 
            linespacing = linespacing)
        
    #시도 경계를 그린다.
    for path in BORDER_LINES:
        ys, xs = zip(*path)
        plt.plot(xs, ys, c = 'black', lw = 4)
        
    plt.gca().invert_yaxis()
    #plt.gca().set_aspect(1)
    plt.axis('off')
    
    cb = plt.colorbar(shrink = .1, aspect = 10)
    cb.set_label(datalabel)
    
    plt.tight_layout()
    plt.savefig('data/' + 'blockMap_' + targetData + '.png')
    plt.show()

# %%
draw_blockMap(data_draw_korea_accident, '사고건수 (건)', '노인 교통사고 건수', 'Blues')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2d143c252c64> in <module>
# ----> 1 draw_blockMap(data_draw_korea_accident, '사고건수 (건)', '노인 교통사고 건수', 'Blues')
#
# <ipython-input-13-93acc5b9105f> in draw_blockMap(blockedMap, targetData, title, color)
#      17
#      18         #광역시는 구 이름이 겹치는 경우가 많아서 시단위 이름도 같이 표시
# ---> 19         if row['광역시도'].endswith('시') and not row['광역시도'].startswith('세종'):
#      20             dispname = '{}\n{}'.format(row['광역시도'][:2], row['행정구역'][:-1])
#      21             if len(row['행정구역']) <= 2:
#
# AttributeError: 'float' object has no attribute 'endswith'
