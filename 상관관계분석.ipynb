# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
font_location = 'c:/Windows/fonts/malgun.ttf'
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 225, 220, 250, 270, 280, 285]
plt.scatter(height, foot_size)
plt.xlabel("키(cm)")
plt.ylabel('발크기(footsize)')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53412 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
h = [100, 200, 300, 400, 500, 600,700,800,900]
t = [18.0, 17.5,17,16.5,15,14.5,13,12,11]
plt.scatter(h,t)
plt.xlabel('산의높이(m)')
plt.ylabel('온도()')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45458 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45458 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np

random_x = np.random.randint(0, 100, 50)
random_y = np.random.randint(0, 100, 50)
plt.scatter(random_x, random_y)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame({'height':height, "foot_size":foot_size})
print(df.corr())
sns.relplot(x='height', y='foot_size',data=df)
# Out:
#              height  foot_size
# height     1.000000   0.953035
# foot_size  0.953035   1.000000

# %%
df=pd.DataFrame({'h':h, 't':t})
print(df.corr())
sns.relplot(x='h', y='t',data=df)
# Out:
#          h        t
# h  1.00000 -0.98792
# t -0.98792  1.00000

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.corr())
sns.relplot(x='x', y='y',data=df)
# Out:
#           x         y
# x  1.000000  0.009739
# y  0.009739  1.000000

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='time')

# %%
import math

def correlation(x, y):
    n = len(x)
    vals = range(n)
    x_sum = 0.0
    y_sum = 0.0
    x_sum_pow = 0.0
    y_sum_pow = 0.0
    mul_xy_sum = 0.0
    
    for i in vals:
        mul_xy_sum = mul_xy_sum + float(x[i]) * float(y[i])
        x_sum = x_sum + float(x[i])
        y_sum = y_sum + float(y[i])
        x_sum_pow = x_sum_pow + pow(float(x[i]), 2)
        y_sum_pow = y_sum_pow + pow(float(y[i]), 2)
        
    try:
        r = ((n * mul_xy_sum) - (x_sum * y_sum)) / math.sqrt( ((n*x_sum_pow) - pow(x_sum, 2)) * ((n*y_sum_pow) - pow(y_sum, 2)) )
    except:
        print("error")
        r = 0.0
    return r

# %%
h = [100,200,300,400,500,600,700,800,900]
t = [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
print(h)
print(t)
print('상관분석:', correlation(h, t))
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900]
# [18.0, 17.5, 17, 16.5, 15, 14.5, 13, 12, 11]
# 상관분석: -0.9879199164035135

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 225, 220, 250, 270, 280, 285]
print(height)
print(foot_size)
print('상관분석:', correlation(height, foot_size))
# Out:
# [100, 120, 130, 140, 150, 160, 170, 180, 190]
# [200, 205, 210, 225, 220, 250, 270, 280, 285]
# 상관분석: 0.9530352910537325

# %%
random_x = np.random.randint(0, 100, 50)
random_y = np.random.randint(0, 100, 50)
print(random_x)
print(random_y)
print('상관분석:', correlation(random_x, random_y))
# Out:
# [89 49 92 39 11 55 37  6 23 93 82 76 34 35 76 87 74 24 58 25 88 42 75 88
#  40 22 61 26 42 33 81 23 71  0 28 77 35 42 66  8 70 47 67 63 61 23  1 24
#  11 48]
# [28 56 13 50 52 79 54  4 59 41 39  1 21 78 48 67 47 87 30 45 31 92  1  8
#  70 32 47 43 15 99 46 28 15 63 22  1 36  9 72 61 97 81 16 45 66 51 93  1
#  48 95]
# 상관분석: -0.24178698870243426

# %% [markdown]
# ## Pandas 사용 상관관계분석

# %%
df=pd.DataFrame({'h':h, 't':t})
print(df.h.corr(df.t))
# Out:
# -0.9879199164035133

# %%
df=pd.DataFrame({'x':random_x, 'y':random_y})
print(df.x.corr(df.y))
# Out:
# -0.24178698870243423

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 225, 220, 250, 270, 280, 285]
list=[height, foot_size]
df=pd.DataFrame(list).T
print(df)
corr=df.corr(method='pearson')
print(corr)
# Out:
#      0    1
# 0  100  200
# 1  120  205
# 2  130  210
# 3  140  225
# 4  150  220
# 5  160  250
# 6  170  270
# 7  180  280
# 8  190  285
#           0         1
# 0  1.000000  0.953035
# 1  0.953035  1.000000

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 225, 220, 250, 270, 280, 285]
weight=[25, 30, 38, 35, 40, 45, 55, 68, 70]
list=[height, foot_size, weight]
df=pd.DataFrame(list).T
print(df)
corr1=df.corr()
print(corr1)
# Out:
#      0    1   2
# 0  100  200  25
# 1  120  205  30
# 2  130  210  38
# 3  140  225  35
# 4  150  220  40
# 5  160  250  45
# 6  170  270  55
# 7  180  280  68
# 8  190  285  70
#           0         1         2
# 0  1.000000  0.953035  0.952271
# 1  0.953035  1.000000  0.963898
# 2  0.952271  0.963898  1.000000

# %% [markdown]
# ## 상관관계 시각화 -heatmap

# %%
df_heatmap = sns.heatmap(corr1, # 상관계수 값
                        cbar=True, # 사이드바 표시
                        annot=True, # 실제값 화면에 표시여부
                        annot_kws={'size':20}, # 글자 크기
                        fmt='.2f', # 소수점 자리수 지정
                        square=True, # 정사각형으로 표시 여부
                        cmap='Blues') # 색상지정, Reds, Greens, Blues

# %%
df_heatmap = sns.heatmap(corr1, # 상관계수 값
                        cbar=True, # 사이드바 표시
                        annot=True, # 실제값 화면에 표시여부
                        annot_kws={'size':20}, # 글자 크기
                        cmap='RdYlBu_r', # red, yellow, blue 색상으로 표시
                        vmin=0.95, vmax=1) # 색상 표시 최대값과 최소값

# %%
tips_corr=tips.corr()
print(tips_corr)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df_heatmap = sns.heatmap(tips_corr, # 상관계수 값
                        cbar=True, # 사이드바 표시
                        annot=True, # 실제값 화면에 표시여부
                        annot_kws={'size':20}, # 글자 크기
                        cmap='RdYlBu_r', # red, yellow, blue 색상으로 표시
                        vmin=0.45, vmax=1) # 색상 표시 최대값과 최소값

# %%
df_heatmap = sns.heatmap(corr1, # 상관계수 값
                        cbar=True, # 사이드바 표시
                        annot=True, # 실제값 화면에 표시여부
                        annot_kws={'size':20}, # 글자 크기
                        cmap='RdYlBu_r', # red, yellow, blue 색상으로 표시
                        vmin=0.95, vmax=1) # 색상 표시 최대값과 최소값

# %%
import numpy as np
fig, ax = plt.subplots(figsize=(7, 7))
mask=np.zeros_like(corr1, dtype=np.bool) # 삼각형 마스크 만들기 위쪽 삼각형에 False
mask[np.triu_indices_from(mask)]=True # 아래쪽 삼각형에 True

df_heatmap = sns.heatmap(corr1, # 상관계수 값
                        cbar_kws={'shrink':.5}, # 컵라바 크기 절반으로 줄이기
                        annot=True, # 실제값 화면에 표시여부
                        mask=mask, # 표시하지 않는 마스크 부분 지정
                        linewidth=.5, # 경계면 시선으로 구분하기
                        cmap='RdYlBu_r', # red, yellow, blue 색상으로 표시
                        vmin=0.92, vmax=1) # 색상 표시 최대값과 최소값
# Out:
# <ipython-input-36-f76b94039b34>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask=np.zeros_like(corr1, dtype=np.bool) # 삼각형 마스크 만들기 위쪽 삼각형에 False
